# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/UN data/SYB67_1_202411_Population, Surface Area and Density.csv")

# %%
df.head()
# Out:
#                    T02 Population, density and surface area Unnamed: 2  \
# 0  Region/Country/Area                                  NaN       Year
# 1                    1        Total, all countries or areas       2010
# 2                    1        Total, all countries or areas       2010
# 3                    1        Total, all countries or areas       2010
# 4                    1        Total, all countries or areas       2010
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                             Series      Value  Footnotes
# 1           Population mid-year estimates (millions)   7,021.73        NaN
# 2  Population mid-year estimates for males (milli...   3,533.14        NaN
# 3  Population mid-year estimates for females (mil...   3,488.59        NaN
# 4                  Sex ratio (males per 100 females)      101.3        NaN
#
#                                           Unnamed: 6
# ...

# %%
# Use first row as header
df.columns = df.iloc[0]
df = df.iloc[1:].reset_index(drop=True)

# Rename second column
df.rename(
    columns={df.columns[1]: "Population, density and surface area"},
    inplace=True
)

# %%
df.head()
# Out:
# 0 Region/Country/Area Population, density and surface area  Year  \
# 0                   1        Total, all countries or areas  2010
# 1                   1        Total, all countries or areas  2010
# 2                   1        Total, all countries or areas  2010
# 3                   1        Total, all countries or areas  2010
# 4                   1        Total, all countries or areas  2010
#
# 0                                             Series     Value  \
# 0           Population mid-year estimates (millions)  7,021.73
# 1  Population mid-year estimates for males (milli...  3,533.14
# 2  Population mid-year estimates for females (mil...  3,488.59
# 3                  Sex ratio (males per 100 females)     101.3
# 4     Population aged 0 to 14 years old (percentage)      27.3
#
# 0                                  Footnotes  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# ...

# %%
first_row_dict = df.iloc[0].to_dict()
print(first_row_dict)
# Out:
# {'Region/Country/Area': '1', 'Population, density and surface area': 'Total, all countries or areas', 'Year': '2010', 'Series': 'Population mid-year estimates (millions)', 'Value': '7,021.73', 'Footnotes': nan, 'Source': 'United Nations Population Division, New York, World Population Prospects: The 2024 Revision, last accessed July 2024.'}

# %%
df.to_csv("/content/drive/MyDrive/UN data/SYB67_1_202411_Population, Surface Area and Density_new.csv")
